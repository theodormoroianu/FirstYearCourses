# %%
import unicodecsv

# %%
def Read():
    with open("enrollments.csv", "rb") as fin:
        reader = unicodecsv.DictReader(fin)
        enrollments = [i for i in reader]
Read()

# %%
enrollments
# Out:
# _key', '463'),
#               ('status', 'current'),
#               ('join_date', '2015-02-09'),
#               ('cancel_date', ''),
#               ('days_to_cancel', ''),
#               ('is_udacity', 'False'),
#               ('is_canceled', 'False')]),
#  OrderedDict([('account_key', '1105'),
#               ('status', 'canceled'),
#               ('join_date', '2015-02-09'),
#               ('cancel_date', '2015-02-13'),
#               ('days_to_cancel', '4'),
#               ('is_udacity', 'False'),
#               ('is_canceled', 'True')]),
#  OrderedDict([('account_key', '284'),
#               ('status', 'canceled'),
#               ('join_date', '2015-02-09'),
#               ('cancel_date', '2015-04-08'),
#               ('days_to_cancel', '58'),
#               ('is_udacity', 'False'),
#               ('is_canceled', 'True')]),
#  OrderedDict([('account_key', '284'),
#               ('status', 'current'),
#               ('join_date', '2015-04-08'),
# ...
